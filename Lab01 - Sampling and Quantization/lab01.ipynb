# %% [markdown]
# **Processamento Digital de Imagens**
#
# Prática de Amostragem e Quantização
#
# Instruções:
# Utilize python e a biblioteca OpenCV para abertura das imagens.

# %% [markdown]
# Grupo:
# Integrantes

# %% [markdown]
# 1)	Utilizando imagem relogio.tif e faça uma reamostragem de seus pixels para 300, 150 e 72 dpi. Sabe-se que a imagem original possui 1250 dpi. Fazer os cálculos por meio do seu algortimo. Não usar o opencv para a conversão

# %%
# type your code here
# Python code to read image
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread("relogio.tif", cv2.IMREAD_GRAYSCALE)

plt.imshow(img, cmap='gray', vmin=0, vmax=255);

print('Tamanho da imagem : ',img.shape)
# convertendo para 300dpi

linhas = img.shape[0]
colunas = img.shape[1];
# Out:
# Tamanho da imagem :  (3692, 2812)

# %%
#Nome: Leonardo Oliveira de Jesus ID: 12111EBI033
import cv2
import matplotlib.pyplot as plt
import numpy as np

img_relogio = cv2.imread("relogio.tif", cv2.IMREAD_GRAYSCALE)

#plt.imshow(img, cmap='gray', vmin=0, vmax=255);

def reamostrar_imagem (imagem,DPI_original,dpi_escolhido):
    salto = int(DPI_original/dpi_escolhido) #DESAFIO: em numero real e arredondar na consulta (vetor _ fazer a media da janela de salto)
    return imagem[::salto,::salto]

DPI_relogio = 1250
dpis_escolhidos = [300,150,72]

img300 = reamostrar_imagem(img_relogio,DPI_relogio,300)
img150 = reamostrar_imagem(img_relogio,DPI_relogio,150)
img72  = reamostrar_imagem(img_relogio,DPI_relogio,72)

print(f"Dimensões 300 DPI: {img300.shape}")
print(f"Dimensões 150 DPI: {img150.shape}")
print(f"Dimensões 72  DPI: {img72.shape}")

# 4. Criar a visualização conjunta (1 linha e 4 colunas)
plt.figure(figsize=(20, 5)) # Define o tamanho da janela (largura, altura)

# Original
plt.subplot(1, 4, 1)
plt.imshow(img_relogio, cmap='gray')
plt.title(f"Original (1250 DPI)\n{img_relogio.shape}")
plt.axis('off')

# 300 DPI
plt.subplot(1, 4, 2)
plt.imshow(img300, cmap='gray')
plt.title(f"300 DPI\n{img300.shape}")
plt.axis('off')

# 150 DPI
plt.subplot(1, 4, 3)
plt.imshow(img150, cmap='gray')
plt.title(f"150 DPI\n{img150.shape}")
plt.axis('off')

# 72 DPI
plt.subplot(1, 4, 4)
plt.imshow(img72, cmap='gray')
plt.title(f"72 DPI\n{img72.shape}")
plt.axis('off')

plt.tight_layout() # Ajusta o espaçamento para não sobrepor títulos
plt.show()
# Out:
# Dimensões 300 DPI: (923, 703)
# Dimensões 150 DPI: (462, 352)
# Dimensões 72  DPI: (218, 166)

# %% [markdown]
# 2)	Utilizando a imagem ctskull-256.tif, refaça a quantização de seus pixels utilizando de 7 a 1 bit(s) por pixel.  Fazer os cálculos por meio do seu algortimo. Não usar o opencv para a conversão

# %%
import numpy as np
import matplotlib.pyplot as plt

img_orig = np.array(Image.open('ctskull-256.tif').convert('L'))

plt.imshow(img_orig, cmap='gray')
plt.title("Imagem Original")
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def quantizar(img_array, bits):
    n_niveis = 2**bits
    img_q = (img_array / 256.0 * n_niveis).astype(np.uint8)
    fator = 255 // (n_niveis - 1)
    return (img_q * fator).astype(np.uint8)

img_orig = np.array(Image.open('ctskull-256.tif').convert('L'))

img_7bits = quantizar(img_orig, 7)
img_6bits = quantizar(img_orig, 6)
img_5bits = quantizar(img_orig, 5)
img_4bits = quantizar(img_orig, 4)
img_3bits = quantizar(img_orig, 3)
img_2bits = quantizar(img_orig, 2)
img_1bit  = quantizar(img_orig, 1)

plt.figure(figsize=(20, 5))

# Original (8 bits presumidos)
plt.subplot(1, 8, 1)
plt.imshow(img_orig, cmap='gray')
plt.title(f"Quantizada: 8 Bits\n(256 níveis)")
plt.axis('off')

# 7 Bits
plt.subplot(1, 8, 2)
plt.imshow(img_7bits, cmap='gray')
plt.title(f"Quantizada: 7 Bits\n(128 níveis)")
plt.axis('off')

# 6 Bits
plt.subplot(1, 8, 3)
plt.imshow(img_6bits, cmap='gray')
plt.title(f"Quantizada: 6 Bits\n(64 níveis)")
plt.axis('off')

# 5 Bits
plt.subplot(1, 8, 4)
plt.imshow(img_5bits, cmap='gray')
plt.title(f"Quantizada: 5 Bits\n(32 níveis)")
plt.axis('off')

# 4 Bits
plt.subplot(1, 8, 5)
plt.imshow(img_4bits, cmap='gray')
plt.title(f"Quantizada: 4 Bits\n(16 níveis)")
plt.axis('off')

# 3 Bits
plt.subplot(1, 8, 6)
plt.imshow(img_3bits, cmap='gray')
plt.title(f"Quantizada: 3 Bits\n(8 níveis)")
plt.axis('off')

# 2 Bits
plt.subplot(1, 8, 7)
plt.imshow(img_2bits, cmap='gray')
plt.title(f"Quantizada: 2 Bits\n(4 níveis)")
plt.axis('off')

# 1 Bit
plt.subplot(1, 8, 8)
plt.imshow(img_1bit, cmap='gray')
plt.title(f"Quantizada: 1 Bit\n(2 níveis)")
plt.axis('off')

plt.tight_layout()
plt.show()
